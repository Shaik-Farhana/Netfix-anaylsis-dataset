# %%
# Netflix Content Trends Analysis 📺
This project explores the Netflix dataset to uncover trends in content releases, genres, and distribution across countries. It serves as a mini case study to practice data cleaning, analysis, and visualization using Python.

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')
df.head()
df.shape
df.info()
df.head()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# ...

# %%
**Dataset Summary:**
- Rows: 8807
- Columns: 12
- Null values in: director, cast, rating, etc.

# %%
# Exploring Netflix content Releases by Year
import seaborn as sns
import matplotlib.pyplot as plt

df['release_year'].value_counts().sort_index().plot(kind='bar', figsize=(12,6))
plt.title("Netflix Releases Over the Years")
plt.xlabel("Year")
plt.ylabel("Number of Releases")
plt.show()

# %%
# Top 10 genre
df['listed_in'].value_counts().head(10).plot(kind='barh', color='purple')
# Out:
# <Axes: ylabel='listed_in'>

# %%
# Shows by country 
df['country'].value_counts().head(10).plot(kind='bar', color='lightblue')
# Out:
# <Axes: xlabel='country'>

# %%
# This chart shows country wise release of Netflix content over the past decade, United States has the hightest number of releases

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='type', palette='dark')
plt.title('TV Shows vs Movies')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12548\100701092.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='dark')
# Text(0.5, 1.0, 'TV Shows vs Movies')

# %%
### 📌 Key Takeaways:
- Movies dominate the Netflix catalog.
- The US produces most of the content.
- Most content is added between 2015–2020.
